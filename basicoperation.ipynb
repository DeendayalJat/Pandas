# %%
import  pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/placement - placement.csv')

# %%
# CHANGEING DATA TYPE
df['cgpa']=df['cgpa'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
#changing values
df['cgpa']=df['cgpa'].add(4)
df
# Out:
#     cgpa  resume_score  placed
# 0     12          6.52       1
# 1     10          5.17       0
# 2     12          8.86       1
# 3     10          7.27       1
# 4     11          7.30       1
# ..   ...           ...     ...
# 95    10          6.38       0
# 96    12          7.76       1
# 97    10          7.78       0
# 98    12          5.63       1
# 99    10          6.61       0
#
# [100 rows x 3 columns]

# %%
r=df['cgpa'].mean()
r
# Out:
# np.float64(10.47)

# %%
r2=df['cgpa'].median()
r2
# Out:
# 10.0

# %%
#filtering the data
#option1
g=df.filter(items=['cgpa','placed'])
g
# Out:
#     cgpa  placed
# 0     12       1
# 1     10       0
# 2     12       1
# 3     10       1
# 4     11       1
# ..   ...     ...
# 95    10       0
# 96    12       1
# 97    10       0
# 98    12       1
# 99    10       0
#
# [100 rows x 2 columns]

# %%
#option2
t = df[['cgpa', 'placed']]
t
# Out:
#     cgpa  placed
# 0      8       1
# 1      6       0
# 2      8       1
# 3      6       1
# 4      7       1
# ..   ...     ...
# 95     6       0
# 96     8       1
# 97     6       0
# 98     8       1
# 99     6       0
#
# [100 rows x 2 columns]

# %%
## axis =0 means row wise operations
s=df.filter(items=[5,6],axis=0)
s
# Out:
#    cgpa  resume_score  placed
# 5    12          6.19       1
# 6     9          7.09       0

# %%
s=df.to_dict() # saving data in dictionary
s
# Out:
# {'cgpa': {0: 12,
#   1: 10,
#   2: 12,
#   3: 10,
#   4: 11,
#   5: 12,
#   6: 9,
#   7: 10,
#   8: 10,
#   9: 11,
#   10: 10,
#   11: 9,
#   12: 10,
#   13: 12,
#   14: 11,
#   15: 12,
#   16: 12,
#   17: 11,
#   18: 9,
#   19: 10,
#   20: 9,
#   21: 10,
#   22: 10,
#   23: 10,
#   24: 12,
#   25: 11,
#   26: 10,
#   27: 9,
#   28: 11,
#   29: 10,
#   30: 11,
#   31: 9,
#   32: 9,
#   33: 12,
#   34: 12,
#   35: 12,
#   36: 12,
#   37: 13,
#   38: 10,
#   39: 11,
#   40: 12,
#   41: 12,
#   42: 10,
#   43: 12,
#   44: 9,
#   45: 12,
#   46: 9,
#   47: 11,
#   48: 9,
#   49: 9,
#   50: 12,
#   51: 10,
#   52: 9,
#   53: 10,
#   54: 9,
#   55: 10,
#   56: 10,
#   57: 10,
#   58: 10,
#   59: 9,
#   60: 9,
#   61: 10,
#   62: 9,
#   63: 12,
#   64: 11,
#   65: 10,
#   66: 12,
#   67: 10,
#   68: 10,
#   69: 12,
#   70: 11,
#   71: 11,
#   72: 11,
#   73: 9,
#   74: 9,
#   75: 10,
#   76: 13,
#   77: 9,
#   78: 9,
#   79: 9,
#   80: 11,
#   81: 10,
#   82: 11,
#   83: 11,
#   84: 9,
# ...

# %%
q=df.to_string() # into string
q
# Out:
# '    cgpa  resume_score  placed\n0     12          6.52       1\n1     10          5.17       0\n2     12          8.86       1\n3     10          7.27       1\n4     11          7.30       1\n5     12          6.19       1\n6      9          7.09       0\n7     10          6.29       0\n8     10          6.71       0\n9     11          7.12       1\n10    10          6.35       0\n11     9          6.54       0\n12    10          7.01       0\n13    12          5.09       1\n14    11          6.25       1\n15    12          5.93       1\n16    12          7.64       1\n17    11          8.71       1\n18     9          5.88       0\n19    10          8.11       1\n20     9          8.06       0\n21    10          7.64       0\n22    10          5.77       0\n23    10          7.13       0\n24    12          6.18       1\n25    11          5.68       1\n26    10          6.47       0\n27     9          6.15       0\n28    11          7.67       1\n29    10          7.30       0\n30   
# ...

# %%
idx=df.columns # know colums of dataframe
idx
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
label=df.columns[0] # index of columns
label
# Out:
# 'cgpa'

# %%
q=df.columns.values # array of colums name
q
# Out:
# array(['cgpa', 'resume_score', 'placed'], dtype=object)

# %%
df['cgpa']=df['cgpa'].subtract(4)

# %%
df['half']=df['cgpa'].where(df['cgpa']>7,other=0)
df.head(6)
# Out:
#    cgpa  resume_score  placed  half
# 0     8          6.52       1     8
# 1     6          5.17       0     0
# 2     8          8.86       1     8
# 3     6          7.27       1     0
# 4     7          7.30       1     0
# 5     8          6.19       1     8

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
top_left_corner=df.iloc[:5,:3]
top_left_corner
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
top_left_corner_loc=df.loc[:5,['cgpa','placed']]
top_left_corner_loc
# Out:
#    cgpa  placed
# 0  8.14       1
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1
# 4  7.52       1
# 5  8.77       1

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
df.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df=df.dropna()

# %%
i=df.ndim
i
# Out:
# 2

# %%
t=df.shape
t
# Out:
# (100, 3)

# %%
print(df.shape[0]) # rows
print(df.shape[1]) # columns
# Out:
# 100
# 3

# %%
d=df.size
d
# Out:
# 300

# %%
a=df.values # get numpy array
a

# %%
df=df.copy

# %%
df=pd.read_csv('/content/placement - placement.csv')
p=df.sort_values(by = 'resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %% [markdown]
# data->
# 1.numerical->continous->we can divide further
# eg salary weight
# 2.categorocal->descrete->we canot divide further
# eg gender number of employees

# %%
# tips dataset
# categorical clum = numerical colum using map
# rows,column loc,iloc,1 colum sort

# %%
tp=pd.read_csv('/content/tips - tips.csv')

# %%
tp.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#rows between 11 to 13
#t1=tp.filter(items=[11,13],axis=0)
t1=tp.iloc[11:14]
t1
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4

# %%
p=tp.filter(items=['tip','sex','day'])
p
# Out:
#       tip     sex   day
# 0    1.01  Female   Sun
# 1    1.66    Male   Sun
# 2    3.50    Male   Sun
# 3    3.31    Male   Sun
# 4    3.61  Female   Sun
# ..    ...     ...   ...
# 239  5.92    Male   Sat
# 240  2.00  Female   Sat
# 241  2.00    Male   Sat
# 242  1.75    Male   Sat
# 243  3.00  Female  Thur
#
# [244 rows x 3 columns]

# %%
#rename 2 columns
p=p.rename(columns={'tip':'tip_amount','sex':'gender'})
p
# Out:
#      tip_amount  gender   day
# 0          1.01  Female   Sun
# 1          1.66    Male   Sun
# 2          3.50    Male   Sun
# 3          3.31    Male   Sun
# 4          3.61  Female   Sun
# ..          ...     ...   ...
# 239        5.92    Male   Sat
# 240        2.00  Female   Sat
# 241        2.00    Male   Sat
# 242        1.75    Male   Sat
# 243        3.00  Female  Thur
#
# [244 rows x 3 columns]

# %%
tp['male_customer']=tp['sex'].where(tp['sex']=='Male',other=0)
tp
# Out:
#      total_bill   tip     sex smoker   day    time  size male_customer
# 0            16  1.01  Female     No   Sun  Dinner     2             0
# 1            10  1.66    Male     No   Sun  Dinner     3          Male
# 2            21  3.50    Male     No   Sun  Dinner     3          Male
# 3            23  3.31    Male     No   Sun  Dinner     2          Male
# 4            24  3.61  Female     No   Sun  Dinner     4             0
# ..          ...   ...     ...    ...   ...     ...   ...           ...
# 239          29  5.92    Male     No   Sat  Dinner     3          Male
# 240          27  2.00  Female    Yes   Sat  Dinner     2             0
# 241          22  2.00    Male    Yes   Sat  Dinner     2          Male
# 242          17  1.75    Male     No   Sat  Dinner     2          Male
# 243          18  3.00  Female     No  Thur  Dinner     2             0
#
# [244 rows x 8 columns]

# %%
#datatype of each colums and top 6 data ,export to csv,excel
p=tp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   total_bill     244 non-null    int64
#  1   tip            244 non-null    float64
#  2   sex            244 non-null    object
#  3   smoker         244 non-null    object
#  4   day            244 non-null    object
#  5   time           244 non-null    object
#  6   size           244 non-null    int64
#  7   male_customer  244 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 15.4+ KB

# %%
tp.head(6)
# Out:
#    total_bill   tip     sex smoker  day    time  size male_customer
# 0          16  1.01  Female     No  Sun  Dinner     2             0
# 1          10  1.66    Male     No  Sun  Dinner     3          Male
# 2          21  3.50    Male     No  Sun  Dinner     3          Male
# 3          23  3.31    Male     No  Sun  Dinner     2          Male
# 4          24  3.61  Female     No  Sun  Dinner     4             0
# 5          25  4.71    Male     No  Sun  Dinner     4          Male

# %%
p=tp.to_csv('tips11.csv')
q=tp.to_excel('tips11.xlsx')

# %%
#totalbill=integer
tp['total_bill']=tp['total_bill'].astype(int)
tp
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0            16  1.01  Female     No   Sun  Dinner     2
# 1            10  1.66    Male     No   Sun  Dinner     3
# 2            21  3.50    Male     No   Sun  Dinner     3
# 3            23  3.31    Male     No   Sun  Dinner     2
# 4            24  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239          29  5.92    Male     No   Sat  Dinner     3
# 240          27  2.00  Female    Yes   Sat  Dinner     2
# 241          22  2.00    Male    Yes   Sat  Dinner     2
# 242          17  1.75    Male     No   Sat  Dinner     2
# 243          18  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tp.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tp.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
tp.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tp['sex']=tp['sex'].map({'Female':0,'Male':1})

# %%
tp.head()
# Out:
#    total_bill   tip  sex smoker  day    time  size
# 0       16.99  1.01    0     No  Sun  Dinner     2
# 1       10.34  1.66    1     No  Sun  Dinner     3
# 2       21.01  3.50    1     No  Sun  Dinner     3
# 3       23.68  3.31    1     No  Sun  Dinner     2
# 4       24.59  3.61    0     No  Sun  Dinner     4

# %%
top_left_corner_tip=tp.iloc[:5,:3]
top_left_corner_tip
# Out:
#    total_bill   tip  sex
# 0       16.99  1.01    0
# 1       10.34  1.66    1
# 2       21.01  3.50    1
# 3       23.68  3.31    1
# 4       24.59  3.61    0

# %%
top_left_corner_tip_loc1=tp.loc[:5,['tip','sex']]
top_left_corner_tip_loc1
# Out:
#     tip  sex
# 0  1.01    0
# 1  1.66    1
# 2  3.50    1
# 3  3.31    1
# 4  3.61    0
# 5  4.71    1

# %%
tp.sort_values(by='tip')
# Out:
#      total_bill    tip  sex smoker   day    time  size
# 92         5.75   1.00    0    Yes   Fri  Dinner     2
# 111        7.25   1.00    0     No   Sat  Dinner     1
# 67         3.07   1.00    0    Yes   Sat  Dinner     1
# 236       12.60   1.00    1    Yes   Sat  Dinner     2
# 0         16.99   1.01    0     No   Sun  Dinner     2
# ..          ...    ...  ...    ...   ...     ...   ...
# 141       34.30   6.70    1     No  Thur   Lunch     6
# 59        48.27   6.73    1     No   Sat  Dinner     4
# 23        39.42   7.58    1     No   Sat  Dinner     4
# 212       48.33   9.00    1     No   Sat  Dinner     4
# 170       50.81  10.00    1    Yes   Sat  Dinner     3
#
# [244 rows x 7 columns]

# %%
tp.head()
# Out:
#    total_bill   tip  sex smoker  day    time  size
# 0       16.99  1.01    0     No  Sun  Dinner     2
# 1       10.34  1.66    1     No  Sun  Dinner     3
# 2       21.01  3.50    1     No  Sun  Dinner     3
# 3       23.68  3.31    1     No  Sun  Dinner     2
# 4       24.59  3.61    0     No  Sun  Dinner     4

# %%
tp['smoker']=tp['smoker'].map({'No':0,'Yes':1})

# %%
#check unique values of day
tp['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
tp['day']=tp['day'].map({'Thur':0,'Fri':1,'Sat':2,'Sun':3})

# %%
tp['time'].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
tp['time']=tp['time'].map({'Lunch':0,'Dinner':1})

# %%
tp
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 0         16.99  1.01    0       0    3     1     2
# 1         10.34  1.66    1       0    3     1     3
# 2         21.01  3.50    1       0    3     1     3
# 3         23.68  3.31    1       0    3     1     2
# 4         24.59  3.61    0       0    3     1     4
# ..          ...   ...  ...     ...  ...   ...   ...
# 239       29.03  5.92    1       0    2     1     3
# 240       27.18  2.00    0       1    2     1     2
# 241       22.67  2.00    1       1    2     1     2
# 242       17.82  1.75    1       0    2     1     2
# 243       18.78  3.00    0       0    0     1     2
#
# [244 rows x 7 columns]
