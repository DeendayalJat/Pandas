# %%
import pandas as pd

# %%
df=pd.read_csv('/content/covid_toy - covid_toy.csv')
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
### top data check , we will use df.head() , by default it returns top 5 rows.
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
### bottom data chrck,we will use df.tail() , by default it returns last 5 rows.
df.tail(3)
# Out:
#     age  gender  fever   cough       city has_covid
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
### If you want random indexed data , then we will use df.sample().By default it will
# return single row.
df.sample()
# Out:
#    age  gender  fever cough    city has_covid
# 4   65  Female  101.0  Mild  Mumbai        No

# %%
#### If we want to check data type of each column . df.dtypes
df.dtypes
# Out:
# age            int64
# gender        object
# fever        float64
# cough         object
# city          object
# has_covid     object
# dtype: object

# %%
### If we want to check overall information then we will use df.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    object
#  2   fever      90 non-null     float64
#  3   cough      100 non-null    object
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
# x = 0-100
# 50% = 50
# x = 1,2,3,4,5
# mean = (1+2+3+4+5)/5 = 15/5 = 3

# %%
# If you want to check statical view of data , then you can use df.describe()

# %%
df.describe()
# Out:
#               age       fever
# count  100.000000   90.000000
# mean    44.220000  100.844444
# std     24.878931    2.054926
# min      5.000000   98.000000
# 25%     20.000000   99.000000
# 50%     45.000000  101.000000
# 75%     66.500000  102.750000
# max     84.000000  104.000000

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
### If you want to check missing data in df, then you will use df.isnull().sum()

# %%
df.isnull().sum()  ### here fever has 10 missing values .
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
# x = 1,2,3,NaN, 5
# mean = (1+2+3+5)/4 = 11/4 = 2.75
# we will fill this value in this missing data .
# x = 1,2,3,2.75, 5

# %%
df['fever'] = df['fever'].fillna(df['fever'].mean())

# %%
# df.isnull().sum()

# %%
df.head(1)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No

# %%
###If you have categorical data, and you want to check total sub-categories then
# we will use df['column_name'].value_counts()

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
### Machine ---> Numbers --->

# %%
df['gender'] = df['gender'].map({"Female":1 , "Male":0})

# %%
# df.head(5)

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
df['cough'] = df['cough'].map({"Mild":0 , "Strong":1})

# %%
# df.sample(5)

# %%
# has_covid , city
df['has_covid']=df['has_covid'].map({"Yes":1 , "No":0})
df.head(5)
# Out:
#    age  gender  fever  cough     city  has_covid
# 0   60       0  103.0      0  Kolkata          0
# 1   27       0  100.0      0    Delhi          1
# 2   42       0  101.0      0    Delhi          0
# 3   31       1   98.0      0  Kolkata          0
# 4   65       1  101.0      0   Mumbai          0

# %%
df['city']=df['city'].map({"Mumbai":0 , "Delhi":1,"Kolkata":2,"Bangalore":3})
#df.head(10)
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       0  103.0      0     2          0
# 1   27       0  100.0      0     1          1
# 2   42       0  101.0      0     1          0
# 3   31       1   98.0      0     2          0
# 4   65       1  101.0      0     0          0

# %%
df.head(10)
# Out:
#    age  gender       fever  cough  city  has_covid
# 0   60       0  103.000000      0     2          0
# 1   27       0  100.000000      0     1          1
# 2   42       0  101.000000      0     1          0
# 3   31       1   98.000000      0     2          0
# 4   65       1  101.000000      0     0          0
# 5   84       1  100.844444      0     3          1
# 6   14       0  101.000000      1     3          0
# 7   20       1  100.844444      1     0          1
# 8   19       1  100.000000      1     3          0
# 9   64       1  101.000000      0     1          0
